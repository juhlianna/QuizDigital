# %% [markdown]
# <a href="https://colab.research.google.com/github/juhlianna/QuizDigital/blob/main/QuizDigital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import random

# Função para carregar as perguntas do arquivo JSON
def carregar_perguntas(nome_arquivo):
    """Lê o arquivo JSON e retorna a lista de perguntas."""
    try:
        with open(nome_arquivo, 'r', encoding='utf-8') as f:
            perguntas = json.load(f)
        # Opcional: Embaralhar as perguntas
        random.shuffle(perguntas)
        return perguntas
    except FileNotFoundError:
        print(f"Erro: O arquivo '{nome_arquivo}' não foi encontrado. Certifique-se de que ele foi carregado no Colab.")
        return None
    except json.JSONDecodeError:
        print(f"Erro: O arquivo '{nome_arquivo}' não está em um formato JSON válido.")
        return None

def iniciar_quiz(perguntas):
    """Executa o Quiz, gerenciando as perguntas e a pontuação."""
    if not perguntas:
        print("Não há perguntas para iniciar o quiz.")
        return

    pontuacao_total = 0

    print("--- ?? INÍCIO DO QUIZ: VERDADEIRO, FALSO OU DISCUSSÃO ?? ---")
    print("Responda com V (Verdadeiro), F (Falso) ou D (Discussão).\n")

    for i, q in enumerate(perguntas):
        print("-" * 30)
        print(f"PERGUNTA {i + 1}:")
        print(f"?? {q['pergunta']}")

        while True:
            # No Colab, o input é muito amigável
            resposta_aluno = input("Sua resposta (V/F/D): ").upper().strip()
            if resposta_aluno in ["V", "F", "D"]:
                break
            else:
                print("Resposta inválida. Por favor, digite V, F ou D.")

        # --- Processamento ---
        resposta_correta = q["resposta_correta"]

        if resposta_aluno == resposta_correta:
            pontos_ganhos = q["pontos"]
            pontuacao_total += pontos_ganhos

            print(f"\n? CORRETO! (+{pontos_ganhos} pontos)")
            print(f"   *Explicação:* {q['explicacao']}")
            if resposta_aluno == "D":
                print("\n   **Pontuação de Discussão!** Isso exige análise crítica do conteúdo.")

        else:
            print("\n? INCORRETO.")
            print(f"   A resposta correta era **{resposta_correta}**.")
            print(f"   *Explicação:* {q['explicacao']}")

        print(f"\nPontuação atual: {pontuacao_total}\n")

    # --- Fim do Jogo ---
    print("=" * 30)
    print("--- ?? QUIZ FINALIZADO ---")
    print(f"Sua Pontuação Total Final é: **{pontuacao_total}** pontos!")
    print("=" * 30)


# --- EXECUÇÃO PRINCIPAL NO COLAB ---
if __name__ == "__main__":
    NOME_DO_ARQUIVO = "questões.json"

    # 1. Carrega as perguntas
    quiz_data = carregar_perguntas(NOME_DO_ARQUIVO)

    # 2. Inicia o Quiz
    if quiz_data:
        iniciar_quiz(quiz_data)
# Out:
# --- ?? INÍCIO DO QUIZ: VERDADEIRO, FALSO OU DISCUSSÃO ?? ---
# Responda com V (Verdadeiro), F (Falso) ou D (Discussão).
#
# ------------------------------
# PERGUNTA 1:
# ?? Afirmação: O uso da preposição 'a' é facultativo após o verbo 'obedecer', sendo aceitável tanto 'obedecer as regras' quanto 'obedecer às regras'.
# Sua resposta (V/F/D): V
#
# ? INCORRETO.
#    A resposta correta era **F**.
#    *Explicação:* Falso. O verbo 'obedecer' é transitivo indireto e exige a preposição 'a' (Regência Verbal). Portanto, a crase é obrigatória antes de 'regras' (que pede o artigo 'as'). O correto é 'obedecer **às** regras'.
#
# Pontuação atual: 0
#
# ------------------------------
# PERGUNTA 2:
# ?? Afirmação: No período composto por subordinação, a oração principal é sempre aquela que contém o conectivo (conjunção subordinativa).
# Sua resposta (V/F/D): F
#
# ? CORRETO! (+10 pontos)
#    *Explicação:* Falso. A oração **subordinada** é aquela que contém o conectivo e depende da outra para ter sentido completo. A **principal** é aquela que não possui o conectivo.
#
# Pontuação atual: 10
#
# ------------------------------
# PERGUNTA 3:
# ?? Afirmação: Na frase 'Eles se referiam a documentos antigos', a ocorrência da crase é obrigatória: 'Eles se referiam **à** documentos antigos'.
# Sua resposta (V/F/D): F
#
# ? CORRETO! (+10 pontos)
#    *Explicação:* Falso. A crase (fusão de 'a' preposição + 'a' artigo) nunca ocorre antes de palavras no plural que não estejam precedidas do 'a' no plural. Além disso, 'documentos' é uma palavra masculina, o que já impede o uso do artigo 'a'. O correto seria 'a documentos' (somente preposição).
#
# Pontuação atual: 20
#
# ------------------------------
# PERGUNTA 4:
# ?? Afirmação: A palavra 'pneu' segue a regra geral de acentuação gráfica para oxítonas terminadas em 'u'.
# Sua resposta (V/F/D): V
#
# ? CORRETO! (+10 pontos)
#    *Explicação:* Verdadeiro. Embora 'pneu' seja uma paroxítona (PN-EU), ela não se enquadra na regra de acentuação por terminar em 'u' isolado (como 'bamb**u**' ou 'tat**u**') ou 'i' isolado, que não são acentuadas. Portanto, por não se enquadrar nas regras de acentuação, ela não é acentuada.
#
# Pontuação atual: 30
#
# ------------------------------
# PERGUNTA 5:
# ?? Afirmação: Em Portugal, a colocação pronominal mesoclítica (ex: 'Far-te-ei um favor') é sempre obrigatória no início de frases, enquanto no Brasil a tendência é a próclise ('Eu te farei um favor').
# Sua resposta (V/F/D): D
#
# ? CORRETO! (+15 pontos)
#    *Explicação:* Discussão. A mesóclise é uma regra da norma culta para tempos futuros do indicativo (futuro do presente e futuro do pretérito) quando não há fator de próclise. No entanto, ela não é obrigatória *sempre*, e o seu uso é raríssimo e evitado na fala coloquial. A afirmação exige a distinção entre norma e uso.
#
#    **Pontuação de Discussão!** Isso exige análise crítica do conteúdo.
#
# Pontuação atual: 45
#
# ------------------------------
# PERGUNTA 6:
# ?? Afirmação: A frase 'Fazem dez anos que não o vejo' está gramaticalmente correta em relação à concordância verbal.
# Sua resposta (V/F/D): F
#
# ? CORRETO! (+10 pontos)
#    *Explicação:* Falso. O verbo 'fazer', quando indica tempo decorrido, é impessoal e deve permanecer no singular. O correto é: 'Faz dez anos que não o vejo'.
#
# Pontuação atual: 55
#
# ------------------------------
# PERGUNTA 7:
# ?? Afirmação: O uso de 'Por que' (separado e sem acento) é exclusivo para o início de frases interrogativas diretas.
# Sua resposta (V/F/D): V
#
# ? INCORRETO.
#    A resposta correta era **F**.
#    *Explicação:* Falso. 'Por que' (separado e sem acento) também é usado como pronome relativo, podendo ser substituído por 'pelo qual' (e variações), no meio de frases declarativas. Ex: 'Os motivos **por que** lutamos são nobres'.
#
# Pontuação atual: 55
#
# ------------------------------
# PERGUNTA 8:
# ?? Afirmação: Todas as palavras terminadas em ditongo crescente, como 'história' e 'ciência', são consideradas paroxítonas acentuadas.
# Sua resposta (V/F/D): D
#
# ? CORRETO! (+15 pontos)
#    *Explicação:* Discussão. Embora na prática e pelas regras atuais essas palavras sejam tratadas como **paroxítonas terminadas em ditongo crescente** (e, portanto, acentuadas), elas também podem ser classificadas como **proparoxítonas eventuais ou aparentes** ('his-tó-ri-a'), dependendo do nível de ensino e da análise fonética. O 'D' exige que o aluno reconheça a dupla classificação e a regra aplicada.
#
#    **Pontuação de Discussão!** Isso exige análise crítica do conteúdo.
#
# Pontuação atual: 70
#
# ------------------------------
# PERGUNTA 9:
# ?? Afirmação: O verbo 'haver' no sentido de 'existir' é impessoal e deve ser usado sempre no singular, mesmo quando o objeto é plural.
# Sua resposta (V/F/D): F
#
# ? INCORRETO.
#    A resposta correta era **V**.
#    *Explicação:* Verdadeiro. O verbo 'haver' no sentido de 'existir' ou 'ocorrer' é impessoal, funcionando como um verbo defectivo. Por isso, a concordância é sempre na terceira pessoa do singular. Ex: 'Havia muitos problemas.'
#
# Pontuação atual: 70
#
# ------------------------------
# PERGUNTA 10:
# ?? Afirmação: Na frase 'O professor, meu orientador, aprovou o trabalho.', o termo 'meu orientador' funciona como um aposto explicativo e pode ser retirado sem prejuízo da correção gramatical da frase.
# Sua resposta (V/F/D): D
#
# ? INCORRETO.
#    A resposta correta era **V**.
#    *Explicação:* Verdadeiro. O aposto explicativo é um termo acessório da oração. Sua função é explicar ou detalhar um termo anterior. Por estar entre vírgulas, ele é isolado e pode ser removido, mantendo a estrutura principal: 'O professor aprovou o trabalho.'
#
# Pontuação atual: 70
#
# ==============================
# --- ?? QUIZ FINALIZADO ---
# Sua Pontuação Total Final é: **70** pontos!
# ==============================
